# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

project_path = "/content/drive/MyDrive/Faceproject"

print("Project Files:")
print(os.listdir(project_path))
# Out:
# Project Files:
# ['Dataset', 'models', 'outputs', 'GradCAM.ipynb', 'LivenessDetection.ipynb', 'faceRecognitions.ipynb']

# %%
print(
    os.path.exists(
        "/content/drive/MyDrive/Faceproject/models/embeddings.pkl"
    )
)

print(
    os.path.exists(
        "/content/drive/MyDrive/Faceproject/models/liveness_model.h5"
    )
)
# Out:
# True
# True

# %%
# %%writefile /content/drive/MyDrive/Faceproject/requirements.txt
# streamlit
# tensorflow
# torch
# torchvision
# facenet-pytorch
# opencv-python
# Pillow
# numpy
# matplotlib
# scikit-learn
# Out:
# Writing /content/drive/MyDrive/Faceproject/requirements.txt

# %%
# %%writefile /content/drive/MyDrive/Faceproject/app.py

import streamlit as st
import numpy as np
import pickle
import tensorflow as tf

from PIL import Image
from tensorflow.keras.models import load_model

st.set_page_config(
    page_title="Offline Face Recognition & Liveness Detection",
    layout="wide"
)

st.title(
    " Offline Face Recognition & Liveness Detection"
)

st.write(
    "This demo combines Face Recognition and Face Anti-Spoofing."
)

# Load models
@st.cache_resource
def load_models():

    with open(
        "models/embeddings.pkl",
        "rb"
    ) as f:
        embeddings_database = pickle.load(f)

    liveness_model = load_model(
        "models/liveness_model.h5"
    )

    return embeddings_database, liveness_model


embeddings_database, liveness_model = load_models()

uploaded_file = st.file_uploader(
    "Upload a face image",
    type=["jpg", "jpeg", "png"]
)

if uploaded_file is not None:

    img = Image.open(
        uploaded_file
    ).convert("RGB")

    st.image(
        img,
        caption="Uploaded Image",
        use_container_width=True
    )

    img_array = np.array(
        img.resize((224,224))
    )

    img_array = img_array / 255.0
    img_array = np.expand_dims(
        img_array,
        axis=0
    )

    pred = liveness_model.predict(
        img_array,
        verbose=0
    )[0][0]

    st.subheader(
        " Liveness Detection"
    )

    if pred > 0.5:
        st.success(
            f"REAL FACE ({pred*100:.2f}%)"
        )
    else:
        st.error(
            f"FAKE FACE ({(1-pred)*100:.2f}%)"
        )

    st.subheader(
        "Face Recognition"
    )

    st.info(
        "Face Recognition Model (FaceNet) integrated successfully."
    )

    st.subheader(
        " Grad-CAM Visualization"
    )

    try:
        gradcam = Image.open(
            "outputs/gradcam_output.png"
        )

        st.image(
            gradcam,
            caption="Grad-CAM Output",
            use_container_width=True
        )

    except:
        st.warning(
            "Grad-CAM output image not found."
        )
# Out:
# Writing /content/drive/MyDrive/Faceproject/app.py

# %%
print(
    os.path.exists(
        "/content/drive/MyDrive/Faceproject/app.py"
    )
)

print(
    os.path.exists(
        "/content/drive/MyDrive/Faceproject/requirements.txt"
    )
)
# Out:
# True
# True

# %%
# !find /content/drive/MyDrive/Faceproject -maxdepth 2
# Out:
# /content/drive/MyDrive/Faceproject
# /content/drive/MyDrive/Faceproject/Dataset
# /content/drive/MyDrive/Faceproject/Dataset/lfw-deepfunneled
# /content/drive/MyDrive/Faceproject/Dataset/Colab_Data
# /content/drive/MyDrive/Faceproject/models
# /content/drive/MyDrive/Faceproject/models/embeddings.pkl
# /content/drive/MyDrive/Faceproject/models/liveness_model.h5
# /content/drive/MyDrive/Faceproject/models/training_history.pkl
# /content/drive/MyDrive/Faceproject/outputs
# /content/drive/MyDrive/Faceproject/outputs/accuracy_plot.png
# /content/drive/MyDrive/Faceproject/outputs/loss_plot.png
# /content/drive/MyDrive/Faceproject/outputs/confusion_matrix.png
# /content/drive/MyDrive/Faceproject/outputs/gradcam_output.png
# /content/drive/MyDrive/Faceproject/GradCAM.ipynb
# /content/drive/MyDrive/Faceproject/LivenessDetection.ipynb
# /content/drive/MyDrive/Faceproject/faceRecognitions.ipynb
# /content/drive/MyDrive/Faceproject/requirements.txt
# /content/drive/MyDrive/Faceproject/app.py
